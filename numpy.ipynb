# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'event' : ['concert', 'wedding', 'conference'],
    'date' : ['2025-05-01', '2025-08-04','2024-08-05']
})

# %%
df['date_pd'] = pd.to_datetime(df['date'])
print(df.dtypes[['event','date_pd']])
# Out:
# event              object
# date_pd    datetime64[ns]
# dtype: object

# %%
A = np.array([[1,2,3],[1,2,3]])
B = np.array([[1,2],[1,2]])

# %%
np.dot(A,B.T)

# %%
ind = [0,2,-1]
matrix[ind]

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
panda_data = pd.Series([10,20,30,40,50], index=("a","c","f","r","q"), name="troop")
print(panda_data)

# %%
data = {'a':10, 'b':20, 'c':30,'d':40}
line = pd.Series(data)
print(line.loc['a'])

# %%
a = np.array([[1,2],[3,4],[5,6]])
b = a.flatten()
print(b)

# %%
data = np.array([[1,2],[3,4],[7,8]])

df = pd.DataFrame(data, columns=['a','b'])
print(df.loc[0])

# %%
titanic_dataset = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

# %%
df = pd.read_csv(titanic_dataset)

# %%
df.tail()

# %%
df[(df['Age'] <70) & (df['Survived']==1)][['Name','Sex']]

# %%
survive = len(df[df['Survived'] == 1])
not_survive = len(df) - survive
print("Percentage of survivors:", survive / len(df))
print(not_survive)
# Out:
# Percentage of survivors: 0.3838383838383838
# 549
